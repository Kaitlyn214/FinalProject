# %%
import pandas as pd
import numpy as np
import requests

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json

import random

from IPython.display import Image 
from IPython.core.display import HTML 
from IPython.display import display_html
from geopy.geocoders import Nominatim

import requests 
from pandas.io.json import json_normalize

# !pip install beautifulsoup4
# !pip install lxml


# !conda install -c conda-forge folium=0.5.0 --yes
import folium 
import matplotlib.cm as cm
import matplotlib.colors as colors

from sklearn.cluster import KMeans
from bs4 import BeautifulSoup

print('Libraries Imported and Packages Installed')
# Out:
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python-3.8-main
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     branca-0.4.2               |     pyhd8ed1ab_0          26 KB  conda-forge
#     certifi-2021.10.8          |   py38h578d9bd_1         145 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     python_abi-3.8             |           2_cp38           4 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     widgetsnbextension-3.5.1   |   py38h578d9bd_4         1.8 MB  conda-forge
# ...

# %%
# Scraping Cities List

page = requests.get("https://simple.wikipedia.org/wiki/Category:Cities_in_Indiana")
soup = BeautifulSoup(page.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Category:Cities in Indiana - Simple English Wikipedia, the free encyclopedia
#   </title>
#   <script>
# ...

# %%
CitiesList = []
for row in soup.findAll("li"): CitiesList.append(row.text)

# %%
cl_df = pd.DataFrame({"City": CitiesList})
cl_df.head()
# Out:
#                                   City
# 0               Brazil, Indiana‎ (4 P)
# 1      Evansville, Indiana‎ (1 C, 2 P)
# 2    Indianapolis, Indiana‎ (3 C, 7 P)
# 3            List of cities in Indiana
# 4                  Alexandria, Indiana

# %%
# Data Cleaning
cl_df.drop([0, 1, 2, 3, 122, 123, 124, 125, 126, 127, 128, 129, 130, 131, 132, 133, 134, 135, 136, 137, 138, 139, 140, 141, 142, 143, 144, 145, 146, 147, 
            148, 149, 150, 151, 152, 153, 154, 155, 156, 157, 158, 159, 160, 161, 162, 163, 164, 165, 166, 167, 168, 169, 170, 171, 172, 173, 174, 175, 
            176, 177, 178, 179, 180, 181, 182, 183, 184, 185, 186, 187, 188, 189, 190, 191, 192, 193, 194, 195, 196, 197, 198, 199, 200, 201, 202, 203, 
            204, 205, 206, 207, 208, 209, 210, 211, 212, 213, 214, 215, 216, 217, 218, 219, 220, 221, 222, 223, 224, 225, 226, 227, 228, 229, 230, 231, 
            232, 233, 234, 235, 236, 237, 238, 239, 240], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/wsuser/ipykernel_154/3819700836.py in <module>
#       1 # Data Cleaning
#       2 # Dropping Cities with vegan/vegetarian restaurants and restaurants with vegan/vegetarian options
# ----> 3 cl_df.drop([0, 1, 2, 3, 122, 123, 124, 125, 126, 127, 128, 129, 130, 131, 132, 133, 134, 135, 136, 137, 138, 139, 140, 141, 142, 143, 144, 145, 146, 147,
#       4             148, 149, 150, 151, 152, 153, 154, 155, 156, 157, 158, 159, 160, 161, 162, 163, 164, 165, 166, 167, 168, 169, 170, 171, 172, 173, 174, 175,
#       5             176, 177, 178, 179, 180, 181, 182, 183, 184, 185, 186, 187, 188, 189, 190, 191, 192, 193, 194, 195, 196, 197, 198, 199, 200, 201, 202, 203,
#
# /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
# Dropping Cities with vegan/vegetarian restaurants and restaurants with vegan/vegetarian options

cl_df.drop([15, 29, 37, 41, 61, 63, 72, 80, 82, 85, 105, 109, 112, 5, 6, 21, 25, 34, 36, 43, 49, 50, 62, 71, 74, 75, 86, 96, 115, 117, 118, 11, 39, 
            42, 44, 47, 48, 65, 66, 77, 83, 95], inplace=True)

# %%
# Out:
#                         City
# 4        Alexandria, Indiana
# 7            Attica, Indiana
# 8            Auburn, Indiana
# 9            Aurora, Indiana
# 10       Batesville, Indiana
# 12      Beech Grove, Indiana
# 13            Berne, Indiana
# 14         Bicknell, Indiana
# 16         Bluffton, Indiana
# 17        Boonville, Indiana
# 18         Brighton, Indiana
# 19           Butler, Indiana
# 20        Cannelton, Indiana
# 22      Charlestown, Indiana
# 23          Clinton, Indiana
# 24    Columbia City, Indiana
# 26     Connersville, Indiana
# 27        Covington, Indiana
# 28   Crawfordsville, Indiana
# 30          Decatur, Indiana
# 31           Delphi, Indiana
# 32          Dunkirk, Indiana
# 33     East Chicago, Indiana
# 35           Elwood, Indiana
# 38        Frankfort, Indiana
# 40          Garrett, Indiana
# 45      Greencastle, Indiana
# 46        Greendale, Indiana
# 51    Hartford City, Indiana
# 52           Hobart, Indiana
# 53      Huntingburg, Indiana
# ...

# %%
#Dropping Cities with a population <20000
cl_df.drop([4, 7, 8, 9, 10, 12, 13, 14, 16, 17, 19, 20, 22, 23, 
            24, 26, 27, 28, 30, 31, 32, 35, 38, 40, 45, 46, 51,
            53, 54, 55, 56, 58, 59, 60, 64, 67, 68, 69, 70, 73, 
            76, 78, 79, 81, 84, 87, 88, 89, 90, 91, 93, 94, 97,
            98, 99, 100, 101, 102, 106, 107, 108, 110, 111, 113,
            114, 116, 119, 120, 121], inplace=True)

# %%
cl_df
# Out:
#                         City
# 18         Brighton, Indiana
# 33     East Chicago, Indiana
# 52           Hobart, Indiana
# 57   Jeffersonville, Indiana
# 92          Portage, Indiana
# 103         Seymour, Indiana
# 104     Shelbyville, Indiana
